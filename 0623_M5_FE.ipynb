# %%
import pandas as pd 
import numpy as np

from  datetime import datetime, timedelta
import gc
import numpy as np, pandas as pd
import lightgbm as lgb

# %%
from datetime import datetime

# %%
ca = pd.read_csv("C:\Eric\CA_SNAP_BN.csv")
wi = pd.read_csv("C:\Eric\WI_SNAP_BN.csv")
tx = pd.read_csv("C:\Eric\TX_SNAP_BN.csv")

# %%
tr = pd.read_csv("C:\Eric\sales_train_validation.csv")
cal = pd.read_csv("C:\Eric\calendar.csv")

# %%
BN_list = [ca, wi, tx]

# for i in BN_list:
#     i['date'] = pd.to_datetime(i['date'],errors='coerce')

ca.columns = ['date', 'recipient']
wi.columns = ['date', 'recipient']
tx.columns = ['date', 'recipient']

ca['date'] = pd.to_datetime(ca.date, errors='coerce')
wi['date'] = pd.to_datetime(wi.date, errors='coerce')
tx['date'] = pd.to_datetime(tx.date, errors='coerce')

# date col에서 month 뽑아내기 
ca['date_month'] = ca['date'].dt.strftime('%m')
wi['date_month'] = wi['date'].dt.strftime('%m')
tx['date_month'] = tx['date'].dt.strftime('%m')

# date col에서 year 뽑아내기 
ca['date_year'] = ca['date'].dt.strftime('%Y')
wi['date_year'] = wi['date'].dt.strftime('%Y')
tx['date_year'] = tx['date'].dt.strftime('%Y')

# %%
ca.date_month = pd.to_numeric(ca.date_month)

# %%
t002.year = pd.to_numeric(t002.year)

# %%
# ca 'date_month'  'date_year'

# %%
ca = ca.rename(columns = {'date_month':'month'} )
wi = ca.rename(columns = {'date_month':'month'} )
tx = ca.rename(columns = {'date_month':'month'} )

ca = ca.rename(columns = {'date_year':'year'} )
wi = ca.rename(columns = {'date_year':'year'} )
tx = ca.rename(columns = {'date_year':'year'} )

# %%
# cal 'date', 'month' ,' year', 'd'

# %% [markdown]
# * Slice date and make sample

# %%
# cal 데이터에서 100개 
t001 = cal[0:100]
# ca_recipient 데이터에서 50개 
t002= ca

# ca.shape 
(450, 4)
# cal.shape
(1969, 14)
# Out:
# (1969, 14)

# %%
a009 = pd.merge(t001, t002, on="month", how="left" )

# %%
a009.shape
# Out:
# (431, 17)

# %%
a007 = pd.merge(t001, t002, on=["month","year"], how="left" )

# %%
a008.shape
# Out:
# (100, 16)

# %%
t001.shape
# Out:
# (100, 14)

# %%
t002.shape
# Out:
# (450, 4)

# %%
a007.recipient
# Out:
# 0     3602170
# 1     3602170
# 2     3602170
# 3     3619055
# 4     3619055
# 5     3619055
# 6     3619055
# 7     3619055
# 8     3619055
# 9     3619055
# 10    3619055
# 11    3619055
# 12    3619055
# 13    3619055
# 14    3619055
# 15    3619055
# 16    3619055
# 17    3619055
# 18    3619055
# 19    3619055
# 20    3619055
# 21    3619055
# 22    3619055
# 23    3619055
# 24    3619055
# 25    3619055
# 26    3619055
# 27    3619055
# 28    3619055
# 29    3619055
#        ...
# 70    3679671
# 71    3679671
# 72    3679671
# 73    3679671
# 74    3679671
# 75    3679671
# 76    3679671
# 77    3679671
# 78    3679671
# 79    3679671
# 80    3679671
# 81    3679671
# 82    3679671
# 83    3679671
# 84    3679671
# 85    3679671
# 86    3679671
# 87    3679671
# 88    3679671
# 89    3679671
# 90    3679671
# 91    3679671
# 92    3727005
# 93    3727005
# 94    3727005
# 95    3727005
# 96    3727005
# 97    3727005
# 98    3727005
# 99    3727005
# ...

# %%
ca = ca.rename(columns = {'date_month':'month'} )
wi = ca.rename(columns = {'date_month':'month'} )
tx = ca.rename(columns = {'date_month':'month'} )

# %%
cal01 = cal.copy()

# %%
cal01['recipient'] = pd.merge((ca['month'], cal['month'], on = ))

# %%
ca.columns
# Out:
# Index(['date', 'recipient', 'month'], dtype='object')

# %% [markdown]
# # * Slice date and make sample

# %%
# cal 데이터에서 100개 
t001 = cal[0:100]

# ca_recipient 데이터에서 50개 
t002= ca[0:50]

# %%
t001.head()
# Out:
#         date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1 2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2 2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3 2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4 2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1
#
#                        ch_month                    date_month
# 0 1970-01-01 00:00:00.000000001 1970-01-01 00:00:00.000000001
# ...

# %%
t002.shape
# Out:
# (50, 3)

# %%
# t001.shape = (100,16)
# t002.shape = (50,3)


a009 = pd.merge(t001, t002, on="month", how="left" )

# %%
a002 = pd.merge(cal,ca, on="month", how="left")

# %%
a002.columns
# Out:
# Index(['date_x', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'ch_month', 'date_month', 'date_y',
#        'recipient'],
#       dtype='object')

# %%
cal.shape
# Out:
# (1969, 16)

# %%
ca.head() # year 처리 안했음.. 병신..
# Out:
#         date  recipient  month
# 0 1981-01-01    1597227      1
# 1 1981-02-01    1615981      2
# 2 1981-03-01    1645020      3
# 3 1981-04-01    1635941      4
# 4 1981-05-01    1612883      5

# %%
a002.shape
# Out:
# (73902, 18)

# %%
a002.head()
# Out:
#       date_x  wm_yr_wk   weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 1 2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 2 2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 3 2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 4 2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        0        0        0
# 4          NaN          NaN          NaN        0        0        0
#
#                        ch_month                    date_month     date_y  \
# ...

# %%
s1 = pd.Series([0,1], index =["a","b"] )
s2 = pd.Series([2,3,4], index =["c","d","e"] )
s3 = pd.Series([5,6], index =["f","g"] )

# %%
pd.concat([s1,s2,s3], axis= 1)
# Out:
# C:\Users\Seoul IT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
pd.concat([s1,s2,s3], axis=1, keys=["one","two","threes"])
# Out:
# C:\Users\Seoul IT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    one  two  threes
# a  0.0  NaN     NaN
# b  1.0  NaN     NaN
# c  NaN  2.0     NaN
# d  NaN  3.0     NaN
# e  NaN  4.0     NaN
# f  NaN  NaN     5.0
# g  NaN  NaN     6.0

# %%
ca.month = pd.to_numeric(ca.month)
ca.month[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# Name: month, dtype: int64

# %%
cal.month[0:3]
# Out:
# 0    1
# 1    1
# 2    1
# Name: month, dtype: int64

# %%
df1 = pd.DataFrame( {"key":list("bbacaab"),
                    "data1":range(7)})

df2 = pd.DataFrame( {"key":list("abd"),
                    "data1":range(3)})

# %%
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  data1
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1,df2, on="key")
# Out:
#   key  data1_x  data1_y
# 0   b        0        1
# 1   b        1        1
# 2   b        6        1
# 3   a        2        0
# 4   a        4        0
# 5   a        5        0

# %%
pd.merge(df1, df2, on="key", how="outer")
# Out:
#   key  data1_x  data1_y
# 0   b      0.0      1.0
# 1   b      1.0      1.0
# 2   b      6.0      1.0
# 3   a      2.0      0.0
# 4   a      4.0      0.0
# 5   a      5.0      0.0
# 6   c      3.0      NaN
# 7   d      NaN      2.0

# %%
pd.merge(df1,df2, on="key", how="left")
# Out:
#   key  data1_x  data1_y
# 0   b        0      1.0
# 1   b        1      1.0
# 2   a        2      0.0
# 3   c        3      NaN
# 4   a        4      0.0
# 5   a        5      0.0
# 6   b        6      1.0

# %%
pd.merge(df1, df2, on="key", how="right")
# Out:
#   key  data1_x  data1_y
# 0   b      0.0        1
# 1   b      1.0        1
# 2   b      6.0        1
# 3   a      2.0        0
# 4   a      4.0        0
# 5   a      5.0        0
# 6   d      NaN        2

# %%
# release date 이전의 결측치는 결측치 삭제,, 0은 0으로 처리... 
# 이상치 다루기... 너무 왜곡이 되어 있다 싶으면은.. 
# 노이즈 제거 방법... 여러가지 시도해봐서 ...

# %%
cal.columns # merge on month
# Out:
# Index(['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'ch_month', 'date_month'],
#       dtype='object')

# %%
ca.date[0:3]
# Out:
# 0   1981-01-01
# 1   1981-02-01
# 2   1981-03-01
# Name: date, dtype: datetime64[ns]

# %%
cal.date[0:3]
# Out:
# 0   2011-01-29
# 1   2011-01-30
# 2   2011-01-31
# Name: date, dtype: datetime64[ns]

# %%
a001 = pd.merge(ca,cal, on="date" )
a001.columns
# Out:
# Index(['date', 'snap_ca_recipient', 'date_month_x', 'wm_yr_wk', 'weekday',
#        'wday', 'month', 'year', 'd', 'event_name_1', 'event_type_1',
#        'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI',
#        'ch_month', 'date_month_y'],
#       dtype='object')

# %%
ca.columns =['date', 'snap_ca_recipient','date_month']
ca.columns
# Out:
# Index(['date', 'snap_ca_recipient', 'date_month'], dtype='object')

# %%
cal.columns
# Out:
# Index(['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'ch_month', 'date_month'],
#       dtype='object')

# %%
# Out:
#         date  recipient date_month
# 0 1981-01-01    1597227         01
# 1 1981-02-01    1615981         02
# 2 1981-03-01    1645020         03
# 3 1981-04-01    1635941         04
# 4 1981-05-01    1612883         05

# %%
# 그담에 할일은.. merge 하는거..

# %%
tr = pd.read_csv("C:\\Eric\\sales_train_validation.csv")

# %%
cal = pd.read_csv("C:\\Eric\\calendar.csv")

# %%
cal['ch_month'] = pd.to_datetime(cal.month, errors='coerce')

# %%
cal
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# 5     2011-02-03     11101   Thursday     6      2  2011     d_6
# 6     2011-02-04     11101     Friday     7      2  2011     d_7
# 7     2011-02-05     11102   Saturday     1      2  2011     d_8
# 8     2011-02-06     11102     Sunday     2      2  2011     d_9
# 9     2011-02-07     11102     Monday     3      2  2011    d_10
# 10    2011-02-08     11102    Tuesday     4      2  2011    d_11
# 11    2011-02-09     11102  Wednesday     5      2  2011    d_12
# 12    2011-02-10     11102   Thursday     6      2  2011    d_13
# ...

# %%
cal['date'] = pd.to_datetime(cal['date'], errors='coerce')

# %%
cal['date_month'] = cal['date'].dt.strftime('%y-%m-%d')

# %%
whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# Date        str          06
# ca          DataFrame              date  recipient<...>n\n[450 rows x 3 columns]
# cal         DataFrame               date  wm_yr_wk<...>n[1969 rows x 16 columns]
# datetime    module       <module 'datetime' from '<...>onda3\\lib\\datetime.py'>
# gc          module       <module 'gc' (built-in)>
# lgb         module       <module 'lightgbm' from '<...>\\lightgbm\\__init__.py'>
# now         datetime     2020-06-23 10:39:09.272657
# np          module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd          module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# timedelta   type         <class 'datetime.timedelta'>
# tr          DataFrame                             <...>0490 rows x 1919 columns]

# %%
from datetime import date, timedelta 

sdate = date(2008,8,15)
edate = date(2008,9,15)

delta = edate - sdate

for i in range(delta.days+1):
    day = sdate + timedelta(days=i)
    print(day)
# Out:
# 2008-08-15
# 2008-08-16
# 2008-08-17
# 2008-08-18
# 2008-08-19
# 2008-08-20
# 2008-08-21
# 2008-08-22
# 2008-08-23
# 2008-08-24
# 2008-08-25
# 2008-08-26
# 2008-08-27
# 2008-08-28
# 2008-08-29
# 2008-08-30
# 2008-08-31
# 2008-09-01
# 2008-09-02
# 2008-09-03
# 2008-09-04
# 2008-09-05
# 2008-09-06
# 2008-09-07
# 2008-09-08
# 2008-09-09
# 2008-09-10
# 2008-09-11
# 2008-09-12
# 2008-09-13
# 2008-09-14
# 2008-09-15

# %%
disaster = pd.read_csv("C:\\Eric\\disaster_minji.csv")

# %%
disaster.columns
# Out:
# Index(['disaster_number', 'state', 'declaration_type', 'declaration_date',
#        'incident_type', 'declaration_title', 'ih_program_declared',
#        'ia_program_declared', 'pa_program_declared', 'hm_program_declared',
#        'incident_begin_date', 'incident_end_date', 'fips', 'designated_area',
#        'new_date01', 'new_date02', 'new_date03', 'new_date04'],
#       dtype='object')

# %%
cal.head()
# Out:
#         date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1 2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2 2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3 2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4 2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1
#
#                        ch_month date_month
# 0 1970-01-01 00:00:00.000000001         01
# ...

# %%
# 만드는 예상 col , disaster_ca, disaster_tx, disaster_wi

# %%
cal.date[0:3]
# Out:
# 0   2011-01-29
# 1   2011-01-30
# 2   2011-01-31
# Name: date, dtype: datetime64[ns]

# %%
disaster.new_date03[0:3]
# Out:
# 0    2011-02-27
# 1    2011-02-27
# 2    2011-02-27
# Name: new_date03, dtype: object

# %%
disaster.head()
# Out:
#    disaster_number state declaration_type      declaration_date incident_type  \
# 0             2862    TX               FM  2011-02-28T03:12:00Z          Fire
# 1             2863    TX               FM  2011-02-28T03:25:00Z          Fire
# 2             2864    TX               FM  2011-02-28T03:37:00Z          Fire
# 3             2865    TX               FM  2011-02-28T05:55:00Z          Fire
# 4             2867    TX               FM  2011-03-12T00:32:00Z          Fire
#
#                  declaration_title  ih_program_declared  ia_program_declared  \
# 0  Willow Creek South Fire Complex                    0                    0
# 1                     Matador Fire                    0                    0
# 2          Tanglewood Fire Complex                    0                    0
# 3            Mitchell Fire Complex                    0                    0
# 4                       Enmin Fire                    0                    0
#
# ...

# %%
cal['date'] = pd.to_datetime(cal['date'], errors='coerce')

# %%
cal['date_month'] = cal['date'].dt.strftime('%m')

# %%
# 'incident_begin_date', 'incident_end_date'

# %%
disaster['new_date01'] = pd.to_datetime(disaster.incident_begin_date,errors = 'coerce')
disaster['new_date02'] = pd.to_datetime(disaster.incident_end_date,errors = 'coerce')

# %%
disaster['new_date03'] = disaster['new_date01'].dt.strftime('%Y-%m-%d')
disaster['new_date04'] = disaster['new_date02'].dt.strftime('%Y-%m-%d')

# %%
from datetime import date, timedelta 

sdate = date(2008,8,15) #datetime.date
edate = date(2008,9,15)

delta = edate - sdate

for i in range(delta.days+1):
    day = sdate + timedelta(days=i)

# %%
disaster['new_date02'][4]
# Out:
# Timestamp('2011-03-17 04:00:00')

# %%
disaster['new_date01'][4]
# Out:
# Timestamp('2011-03-11 05:00:00')

# %%
e = disaster['new_date02'][4]
s = disaster['new_date01'][4]

delta01 = e - s 

for i in range(delta01.days+1):
    day = s + timedelta(days=i)
    print(day)
# Out:
# 2011-03-11 05:00:00
# 2011-03-12 05:00:00
# 2011-03-13 05:00:00
# 2011-03-14 05:00:00
# 2011-03-15 05:00:00
# 2011-03-16 05:00:00

# %% [markdown]
# 최종적으로 합칠 모양은... ?

# %%
cal.columns
# Out:
# Index(['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'ch_month', 'date_month'],
#       dtype='object')

# %%
cal.head()
# Out:
#         date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1 2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2 2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3 2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4 2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1
#
#                        ch_month date_month
# 0 1970-01-01 00:00:00.000000001         01
# ...

# %%
# Disaster Col 만들어서 그 날짜에 있었는지, 어떤 종류 였는지 강도는 어땠는지 집어넣기 

merge 쓰면 되지 않을까? !

# %%
disaster.columns
# Out:
# Index(['disaster_number', 'state', 'declaration_type', 'declaration_date',
#        'incident_type', 'declaration_title', 'ih_program_declared',
#        'ia_program_declared', 'pa_program_declared', 'hm_program_declared',
#        'incident_begin_date', 'incident_end_date', 'fips', 'designated_area',
#        'new_date01', 'new_date02', 'new_date03', 'new_date04'],
#       dtype='object')

# %%
disaster['new_date02']
# Out:
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3                     NaT
# 4     2011-03-17 04:00:00
# 5     2011-03-17 04:00:00
# 6     2011-03-17 04:00:00
# 7     2011-04-06 04:00:00
# 8     2011-04-06 04:00:00
# 9     2011-04-08 04:00:00
# 10    2011-02-03 05:00:00
# 11    2011-02-03 05:00:00
# 12    2011-02-03 05:00:00
# 13    2011-02-03 05:00:00
# 14    2011-02-03 05:00:00
# 15    2011-02-03 05:00:00
# 16    2011-02-03 05:00:00
# 17    2011-02-03 05:00:00
# 18    2011-02-03 05:00:00
# 19    2011-02-03 05:00:00
# 20    2011-02-03 05:00:00
# 21    2011-04-23 04:00:00
# 22    2011-04-23 04:00:00
# 23    2011-04-23 04:00:00
# 24    2011-05-15 04:00:00
# 25    2011-05-15 04:00:00
# 26    2011-04-20 04:00:00
# 27    2011-05-12 04:00:00
# 28    2011-05-12 04:00:00
# 29    2011-05-12 04:00:00
#               ...
# 597   2016-06-25 03:59:00
# 598   2016-06-25 03:59:00
# 599   2016-06-25 03:59:00
# 600   2016-06-25 03:59:00
# 601   2016-06-25 03:59:00
# ...

# %%
whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# Date        str          06
# ca          DataFrame              date  recipient<...>n\n[450 rows x 3 columns]
# cal         DataFrame               date  wm_yr_wk<...>n[1969 rows x 16 columns]
# date        type         <class 'datetime.date'>
# datetime    module       <module 'datetime' from '<...>onda3\\lib\\datetime.py'>
# day         date         2008-09-15
# delta       timedelta    31 days, 0:00:00
# disaster    DataFrame         disaster_number stat<...>\n[627 rows x 15 columns]
# edate       date         2008-09-15
# gc          module       <module 'gc' (built-in)>
# i           int          31
# lgb         module       <module 'lightgbm' from '<...>\\lightgbm\\__init__.py'>
# now         datetime     2020-06-23 10:39:09.272657
# np          module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd          module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# ...
