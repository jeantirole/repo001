# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from random import *

# %%
### 한국일보 - 정치

driver = webdriver.Chrome('chromedriver')

contents = []

for page in range(1,14):   # 1~13페이지
    
    url = 'https://www.hankookilbo.com/News/Politics/HA01?Page={}&sDate='.format(page)
    driver.get(url)   # 해당 페이지로 이동

    rand_value = randint(3,5)
    time.sleep(rand_value)
    
    for i in range(1,16):   # 한 페이지 당 15개의 기사
        headlines = driver.find_element_by_xpath('//*[@id="DataFrm"]/ul/li[{}]/div[2]/a/p[1]'.format(i))
        headlines.click()   # 기사 제목 클릭
        
        content = driver.find_element_by_xpath('//*[@id="article_story"]').text   # 기사내용 가져오기
        contents.append(content)
        
        rand_value2 = randint(3,5)
        time.sleep(rand_value2)
        driver.back()   # 뒤로가기
        rand_value3 = randint(3,5)
        time.sleep(rand_value3)
    
    print('{} 페이지 완료'.format(page))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
# 한겨레

driver = webdriver.Chrome('chromedriver')

contents = []

for page in range(1,11):   # 1~10페이지
    
    url = 'http://www.hani.co.kr/arti/politics/list{}.html'.format(page)
    driver.get(url)   # 해당 페이지로 이동

    rand_value = randint(3,5)
    time.sleep(rand_value)
    
    for i in range(1,16):   # 한 페이지 당 15개의 기사
        headlines = driver.find_element_by_xpath('//*[@id="section-left-scroll-in"]/div[3]/div[{}]/div/h4/a'.format(i))
        headlines.click()   # 기사 제목 클릭
        
        content = driver.find_element_by_xpath('//*[@id="a-left-scroll-in"]/div[2]/div/div[2]').text   # 기사내용 가져오기
        contents.append(content)
        
        rand_value2 = randint(3,5)
        time.sleep(rand_value2)
        driver.back()   # 뒤로가기
        rand_value3 = randint(3,5)
        time.sleep(rand_value3)
    
    print('{} 페이지 완료'.format(page))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-3d7e7382325f> in <module>
#      17         headlines.click()   # 기사 제목 클릭
#      18
# ---> 19         content = driver.find_element_by_xpath('//*[@id="a-left-scroll-in"]/div[2]/div/div[2]').text   # 기사내용 가져오기
#      20         contents.append(content)
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...
